# %%
import pandas as pd
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
import csv

# %%
# # 텍스트 파일 28부터 100까지 불러오기
# lines2 = []
# for i in range(28, 100):
#     if i==29:
#         i = i+1
#     if i==36:
#         i = i+1
#     if i==40:
#         i = i+1
#     if i==42:
#         i = i+1
#     if i==44:
#         i = i+1
#     if i==45:
#         i = i+1
#     if i==49:
#         i = i+1
#     if i==52:
#         i = i+1
#     if i==54:
#         i = i+1
#     if i==55:
#         i = i+1
#     if i==56:
#         i = i+1
#     if i==59:
#         i = i+1
#     if i==60:
#         i = i+1
#     if i==65:
#         i = i+1
#     if i==70:
#         i = i+1
#     if i==72:
#         i = i+1
#     if i==75:
#         i = i+1
#     if i==76:
#         i = i+1
#     if i==77:
#         i = i+1
#     if i==78:
#         i = i+1
#     if i==79:
#         i = i+1
#     if i==82:
#         i = i+1
#     if i==83:
#         i = i+1
#     if i==84:
#         i = i+1
#     if i==90:
#         i = i+1
#     if i==92:
#         i = i+1
#     if i==94:
#         i = i+1
#     if i==95:
#         i = i+1
#     if i==96:
#         i = i+1
#     if i==97:
#         i = i+1
#     if i==98:
#         i = i+1
#     if i==99:
#         i = i+1
#         break
        
#     f = open("./피싱 사례 텍스트 파일/case0"+str(i)+".txt", 'r')
#     lines = f.readlines()
#     lines2 = lines2 + lines # 28~100번 까지의 텍스트 파일
#     f.close()

# %%
# # 텍스트 파일 101부터 142까지 불러오기
# for i in range(100, 143):
#     if i==101:
#         i = i+1
#     if i==103:
#         i = i+1
#     if i==105:
#         i = i+1
#     if i==107:
#         i = i+1
#     if i==108:
#         i = i+1
#     if i==110:
#         i = i+1
#     if i==111:
#         i = i+1
#     if i==112:
#         i = i+1
#     if i==114:
#         i = i+1
#     if i==119:
#         i = i+1
#     if i==122:
#         i = i+1
#     if i==123:
#         i = i+1
#     if i==125:
#         i = i+1
#     if i==130:
#         i = i+1
#     if i==131:
#         i = i+1
#     if i==132:
#         i = i+1
#     if i==134:
#         i = i+1
#     if i==135:
#         i = i+1
#     if i==137:
#         i = i+1
#     if i==139:
#         i = i+1
#     if i==140:
#         i = i+1
#     if i==141:
#         i = i+1
#     f = open("./피싱 사례 텍스트 파일/case"+str(i)+".txt", 'r')
#     lines = f.readlines()
#     lines2 = lines2 + lines
#     f.close()

# %%
lines2 = []
f = open("./피싱 사례 텍스트 파일/case045.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case052.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case055.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case056.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case060.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case078.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case084.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case092.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case095.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case096.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case098.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case099.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case103.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case105.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
f = open("./피싱 사례 텍스트 파일/case134.txt", 'r')
lines = f.readlines()
lines2 = lines2 + lines
f.close()

# %%
# 텍스트 전문 소문자로 변환 --> for문 이용
ff = []
for i in range(0, len(lines2)):
    ff1 = lines2[i].lower()
    ff.append(ff1)

# %%
# 텍스트 파일의 전체 list 원소들 중에 '\n'이 있을 시, 제거!
i=0
while i<len(ff):
    if ff[i]=='\n':
        del ff[i]
        i = i-1
    i = i+1

# %%
tokenizer = RegexpTokenizer('[\w]+')

# %%
stop_words = stopwords.words('english')

# %%
# 소문자 변환 및 공백 제거한 리스트들을 이용하여 전부 토큰화!
test = []
ff_c = ff
for i in range(len(ff_c)) :
    tokens = tokenizer.tokenize(ff[i])
    test1 = tokens
    test = test + test1

# %%
# 관사 없애기 --> a, an, the
# 일반 알파벳 없애기 [a-z]
# to, of, and, in, that, is, for 없애기 (--> top10에 존재!)

# %%
# 1) 알파벳 제거
i=0
while i<len(test):
    if test[i]=='a' or test[i]=='b' or test[i]=='c' or test[i]=='d' or test[i]=='e' or test[i]=='f' or test[i]=='g' or test[i]=='h' or test[i]=='i' or test[i]=='j' or test[i]=='k' or test[i]=='l' or test[i]=='m' or test[i]=='n' or test[i]=='o' or test[i]=='p' or test[i]=='q' or test[i]=='r' or test[i]=='s' or test[i]=='t' or test[i]=='u' or test[i]=='v' or test[i]=='w' or test[i]=='x' or test[i]=='y' or test[i]=='z':
        del test[i]
        i = i-1
    i = i+1

# %%
p3 = re.compile('[0-9]')
i=0
while i<len(test):
    m = p3.match(test[i])
    if not str(m)=='None': 
        del test[i]
        i = i-1
    i = i+1

# %%
# 월 삭제
i=0
while i<len(test):
    if test[i]=='january' or \
    test[i]=='february' or \
    test[i]=='march' or \
    test[i]=='april' or \
    test[i]=='may' or \
    test[i]=='june' or \
    test[i]=='july' or \
    test[i]=='august' or \
    test[i]=='september' or \
    test[i]=='october' or \
    test[i]=='november' or \
    test[i]=='december':
        del test[i]
        i = i-1
    i = i+1

# %%
# 숫자 삭제
i=0
while i<len(test):
    if test[i]=='one' or \
    test[i]=='two' or \
    test[i]=='three' or \
    test[i]=='four' or \
    test[i]=='five' or \
    test[i]=='six' or \
    test[i]=='seven' or \
    test[i]=='eight' or \
    test[i]=='nine' or \
    test[i]=='ten' or \
    test[i]=='zero' or \
    test[i]=='hundreds' or \
    test[i]=='thousands' or \
    test[i]=='hundred' or \
    test[i]=='thousand' or \
    test[i]=='million':
        del test[i]
        i = i-1
    i = i+1

# %%
# 2) 관사 조사 등 불용어 제거
i=0
while i<len(test):
    if test[i]=='the' or \
    test[i]=='to' or \
    test[i]=='of' or \
    test[i]=='and' or \
    test[i]=='in' or \
    test[i]=='that' or \
    test[i]=='is' or \
    test[i]=='for' or \
    test[i]=='on' or \
    test[i]=='with' or \
    test[i]=='this' or \
    test[i]=='as' or \
    test[i]=='it' or \
    test[i]=='are' or \
    test[i]=='an' or \
    test[i]=='said' or \
    test[i]=='they' or \
    test[i]=='from' or \
    test[i]=='their' or \
    test[i]=='by' or \
    test[i]=='be' or \
    test[i]=='or' or \
    test[i]=='have' or \
    test[i]=='was' or \
    test[i]=='which' or \
    test[i]=='at' or \
    test[i]=='has' or \
    test[i]=='also' or \
    test[i]=='used' or \
    test[i]=='can' or \
    test[i]=='using' or \
    test[i]=='new' or \
    test[i]=='campaign' or \
    test[i]=='users' or \
    test[i]=='security' or \
    test[i]=='victims' or \
    test[i]=='page' or \
    test[i]=='were' or \
    test[i]=='these' or \
    test[i]=='information' or \
    test[i]=='attack' or \
    test[i]=='attacks' or \
    test[i]=='researchers' or \
    test[i]=='malicious' or \
    test[i]=='threat' or \
    test[i]=='credentials' or \
    test[i]=='user' or \
    test[i]=='attackers' or \
    test[i]=='more' or \
    test[i]=='not' or \
    test[i]=='we' or \
    test[i]=='use' or \
    test[i]=='other' or \
    test[i]=='one' or \
    test[i]=='into' or \
    test[i]=='been' or \
    test[i]=='legitimate' or \
    test[i]=='them' or \
    test[i]=='according' or \
    test[i]=='but' or \
    test[i]=='file' or \
    test[i]=='if' or \
    test[i]=='you' or \
    test[i]=='out' or \
    test[i]=='data' or \
    test[i]=='its' or \
    test[i]=='read' or \
    test[i]=='so' or \
    test[i]=='up' or \
    test[i]=='like' or \
    test[i]=='such' or \
    test[i]=='campaigns' or \
    test[i]=='then' or \
    test[i]=='sent' or \
    test[i]=='will' or \
    test[i]=='all' or \
    test[i]=='he' or \
    test[i]=='being' or \
    test[i]=='services' or \
    test[i]=='threatpost' or \
    test[i]=='365' or \
    test[i]=='when' or \
    test[i]=='who' or \
    test[i]=='minute' or \
    test[i]=='he' or \
    test[i]=='about' or \
    test[i]=='over' or \
    test[i]=='actors' or \
    test[i]=='victim' or \
    test[i]=='first' or \
    test[i]=='customers' or \
    test[i]=='percent' or \
    test[i]=='document' or \
    test[i]=='steal' or \
    test[i]=='make' or \
    test[i]=='many' or \
    test[i]=='pm' or \
    test[i]=='our' or \
    test[i]=='point' or \
    test[i]=='uses' or \
    test[i]=='tactics' or \
    test[i]=='tactic' or \
    test[i]=='recent' or \
    test[i]=='likely' or \
    test[i]=='once' or \
    test[i]=='check' or \
    test[i]=='malware' or \
    test[i]=='many' or \
    test[i]=='pm' or \
    test[i]=='our' or \
    test[i]=='point' or \
    test[i]=='uses' or \
    test[i]=='tactics' or \
    test[i]=='tactic' or \
    test[i]=='recent'or \
    test[i]=='link' or \
    test[i]=='account' or \
    test[i]=='share' or \
    test[i]=='domain' or \
    test[i]=='article' or \
    test[i]=='author' or \
    test[i]=='report' or \
    test[i]=='links' or \
    test[i]=='access' or \
    test[i]=='site' or \
    test[i]=='website' or \
    test[i]=='there' or \
    test[i]=='login' or \
    test[i]=='wrote' or \
    test[i]=='accounts' or \
    test[i]=='including' or \
    test[i]=='click' or \
    test[i]=='well' or \
    test[i]=='would' or \
    test[i]=='could' or \
    test[i]=='people' or \
    test[i]=='than' or \
    test[i]=='group' or \
    test[i]=='address' or \
    test[i]=='attacker' or \
    test[i]=='based' or \
    test[i]=='domains' or \
    test[i]=='web' or \
    test[i]=='sites' or \
    test[i]=='what' or \
    test[i]=='most' or \
    test[i]=='com' or \
    test[i]=='any' or \
    test[i]=='via' or \
    test[i]=='fake' or \
    test[i]=='service' or \
    test[i]=='those' or \
    test[i]=='landing' or \
    test[i]=='code' or \
    test[i]=='actor' or \
    test[i]=='how' or \
    test[i]=='some' or \
    test[i]=='told' or \
    test[i]=='number' or \
    test[i]=='while' or \
    test[i]=='time' or \
    test[i]=='however' or \
    test[i]=='name' or \
    test[i]=='even' or \
    test[i]=='password' or \
    test[i]=='because' or \
    test[i]=='through' or \
    test[i]=='found' or \
    test[i]=='noted' or \
    test[i]=='year' or \
    test[i]=='files' or \
    test[i]=='after' or \
    test[i]=='compromised' or \
    test[i]=='see' or \
    test[i]=='known' or \
    test[i]=='url' or \
    test[i]=='re' or \
    test[i]=='pages' or \
    test[i]=='explained' or \
    test[i]=='system' or \
    test[i]=='only' or \
    test[i]=='get' or \
    test[i]=='just' or \
    test[i]=='cybercriminals' or \
    test[i]=='another' or \
    test[i]=='different' or \
    test[i]=='financial' or \
    test[i]=='same' or \
    test[i]=='take' or \
    test[i]=='added' or \
    test[i]=='server' or \
    test[i]=='real' or \
    test[i]=='example' or \
    test[i]=='your' or \
    test[i]=='download' or \
    test[i]=='websites' or \
    test[i]=='discovered' or \
    test[i]=='last' or \
    test[i]=='post' or \
    test[i]=='research' or \
    test[i]=='within' or \
    test[i]=='observed' or \
    test[i]=='way' or \
    test[i]=='am' or \
    test[i]=='lures' or \
    test[i]=='had' or \
    test[i]=='platform' or \
    test[i]=='now' or \
    test[i]=='various' or \
    test[i]=='credential' or \
    test[i]=='detection' or \
    test[i]=='top' or \
    test[i]=='personal' or \
    test[i]=='proofpoint' or \
    test[i]=='payment' or \
    test[i]=='activity' or \
    test[i]=='lindsey' or \
    test[i]=='before' or \
    test[i]=='where' or \
    test[i]=='order' or \
    test[i]=='both' or \
    test[i]=='source' or \
    test[i]=='around' or \
    test[i]=='trick' or \
    test[i]=='part' or \
    test[i]=='further' or \
    test[i]=='very' or \
    test[i]=='against' or \
    test[i]=='open' or \
    test[i]=='past' or \
    test[i]=='systems' or \
    test[i]=='do' or \
    test[i]=='donnell' or \
    test[i]=='remote' or \
    test[i]=='authentication' or \
    test[i]=='sender' or \
    test[i]=='send' or \
    test[i]=='related' or \
    test[i]=='several' or \
    test[i]=='passwords' or \
    test[i]=='recently' or \
    test[i]=='clicking' or \
    test[i]=='his' or \
    test[i]=='lure' or \
    test[i]=='sensitive' or \
    test[i]=='addresses' or \
    test[i]=='content' or \
    test[i]=='details' or \
    test[i]=='seen' or \
    test[i]=='kit' or \
    test[i]=='work' or \
    test[i]=='set' or \
    test[i]=='urls' or \
    test[i]=='kits' or \
    test[i]=='continue' or \
    test[i]=='no' or \
    test[i]=='should' or \
    test[i]=='team' or \
    test[i]=='since' or \
    test[i]=='appear' or \
    test[i]=='names' or \
    test[i]=='techniques' or \
    test[i]=='hosted' or \
    test[i]=='tools' or \
    test[i]=='march' or \
    test[i]=='instance' or \
    test[i]=='university' or \
    test[i]=='between' or \
    test[i]=='behind' or \
    test[i]=='network' or \
    test[i]=='without' or \
    test[i]=='find' or \
    test[i]=='really' or \
    test[i]=='recipient' or \
    test[i]=='appears' or \
    test[i]=='potential' or \
    test[i]=='similar' or \
    test[i]=='look' or \
    test[i]=='sharepoint' or \
    test[i]=='stealing' or \
    test[i]=='control' or \
    test[i]=='need' or \
    test[i]=='often' or \
    test[i]=='down' or \
    test[i]=='include' or \
    test[i]=='week' or \
    test[i]=='recipients' or \
    test[i]=='documents' or \
    test[i]=='technique' or \
    test[i]=='associated' or \
    test[i]=='active' or \
    test[i]=='much' or \
    test[i]=='update' or \
    test[i]=='software' or \
    test[i]=='method' or \
    test[i]=='firm' or \
    test[i]=='secure' or \
    test[i]=='additional' or \
    test[i]=='ongoing' or \
    test[i]=='universities' or \
    test[i]=='think' or \
    test[i]=='day' or \
    test[i]=='large' or \
    test[i]=='ransomware' or \
    test[i]=='might' or \
    test[i]=='able' or \
    test[i]=='did' or \
    test[i]=='making' or \
    test[i]=='type' or \
    test[i]=='button' or \
    test[i]=='instead' or \
    test[i]=='browser' or \
    test[i]=='back' or \
    test[i]=='redirected' or \
    test[i]=='don' or \
    test[i]=='end' or \
    test[i]=='shows' or \
    test[i]=='called' or \
    test[i]=='sign' or \
    test[i]=='compromise' or \
    test[i]=='intelligence' or \
    test[i]=='included' or \
    test[i]=='asking' or \
    test[i]=='apt' or \
    test[i]=='html' or \
    test[i]=='unique' or \
    test[i]=='form' or \
    test[i]=='specific' or \
    test[i]=='created' or \
    test[i]=='us' or \
    test[i]=='bad' or \
    test[i]=='free' or \
    test[i]=='internet' or \
    test[i]=='popular' or \
    test[i]=='level' or \
    test[i]=='either' or \
    test[i]=='attempts' or \
    test[i]=='device' or \
    test[i]=='looking' or \
    test[i]=='asked' or \
    test[i]=='multiple' or \
    test[i]=='advantage' or \
    test[i]=='avoid' or \
    test[i]=='third' or \
    test[i]=='initial' or \
    test[i]=='come' or \
    test[i]=='text' or \
    test[i]=='stolen' or \
    test[i]=='cofense' or \
    test[i]=='payload' or \
    test[i]=='help' or \
    test[i]=='during' or \
    test[i]=='taking' or \
    test[i]=='brand' or \
    test[i]=='protect' or \
    test[i]=='create' or \
    test[i]=='attachment' or \
    test[i]=='process' or \
    test[i]=='warned' or \
    test[i]=='script' or \
    test[i]=='world' or \
    test[i]=='still' or \
    test[i]=='suspicious' or \
    test[i]=='know' or \
    test[i]=='across' or \
    test[i]=='second' or \
    test[i]=='case' or \
    test[i]=='allows' or \
    test[i]=='due' or \
    test[i]=='profile' or \
    test[i]=='kaspersky' or \
    test[i]=='windows' or \
    test[i]=='host' or \
    test[i]=='full' or \
    test[i]=='employees' or \
    test[i]=='health' or \
    test[i]=='includes' or \
    test[i]=='actually' or \
    test[i]=='identified' or \
    test[i]=='sending' or \
    test[i]=='hackers' or \
    test[i]=='researcher' or \
    test[i]=='javascript' or \
    test[i]=='far' or \
    test[i]=='already' or \
    test[i]=='criminals' or \
    test[i]=='possible' or \
    test[i]=='verify' or \
    test[i]=='wednesday' or \
    test[i]=='leveraging' or \
    test[i]=='operation' or \
    test[i]=='scammers' or \
    test[i]=='vulnerability' or \
    test[i]=='available' or \
    test[i]=='subject' or \
    test[i]=='something' or \
    test[i]=='common' or \
    test[i]=='lookout' or \
    test[i]=='bec' or \
    test[i]=='c2' or \
    test[i]=='here' or \
    test[i]=='comes' or \
    test[i]=='gain' or \
    test[i]=='next' or \
    test[i]=='ve' or \
    test[i]=='previously' or \
    test[i]=='cyber' or \
    test[i]=='encrypted' or \
    test[i]=='factor' or \
    test[i]=='least' or \
    test[i]=='recaptcha' or \
    test[i]=='party' or \
    test[i]=='increase' or \
    test[i]=='convincing' or \
    test[i]=='global' or \
    test[i]=='media' or \
    test[i]=='means' or \
    test[i]=='lot' or \
    test[i]=='request' or \
    test[i]=='believe' or \
    test[i]=='latest' or \
    test[i]=='few' or \
    test[i]=='half' or \
    test[i]=='storage' or \
    test[i]=='linked' or \
    test[i]=='red' or \
    test[i]=='particular' or \
    test[i]=='armorblox' or \
    test[i]=='designed' or \
    test[i]=='each' or \
    test[i]=='execute' or \
    test[i]=='going' or \
    test[i]=='years' or \
    test[i]=='fact' or \
    test[i]=='drive' or \
    test[i]=='always' or \
    test[i]=='easy' or \
    test[i]=='tool' or \
    test[i]=='themed' or \
    test[i]=='fraud' or \
    test[i]=='exe' or \
    test[i]=='asks' or \
    test[i]=='own' or \
    test[i]=='macos' or \
    test[i]=='thursday' or \
    test[i]=='contained' or \
    test[i]=='action' or \
    test[i]=='permissions' or \
    test[i]=='august' or \
    test[i]=='attempt' or \
    test[i]=='deliver' or \
    test[i]=='resources' or \
    test[i]=='development' or \
    test[i]=='successful' or \
    test[i]=='reported' or \
    test[i]=='provide' or \
    test[i]=='become' or \
    test[i]=='contact' or \
    test[i]=='technology' or \
    test[i]=='operations' or \
    test[i]=='tara' or \
    test[i]=='allow' or \
    test[i]=='launch' or \
    test[i]=='version' or \
    test[i]=='earlier' or \
    test[i]=='three' or \
    test[i]=='word' or \
    test[i]=='directory' or \
    test[i]=='variant' or \
    test[i]=='downloaded' or \
    test[i]=='person' or \
    test[i]=='every' or \
    test[i]=='enter' or \
    test[i]=='under' or \
    test[i]=='cybersecurity' or \
    test[i]=='filters' or \
    test[i]=='response' or \
    test[i]=='contain' or \
    test[i]=='support' or \
    test[i]=='getting' or \
    test[i]=='corporate' or \
    test[i]=='http' or \
    test[i]=='potentially' or \
    test[i]=='platforms' or \
    test[i]=='leverage' or \
    test[i]=='working' or \
    test[i]=='seals' or \
    test[i]=='ip' or \
    test[i]=='tuesday' or \
    test[i]=='highly' or \
    test[i]=='chain' or \
    test[i]=='servers' or \
    test[i]=='effective' or \
    test[i]=='call' or \
    test[i]=='say' or \
    test[i]=='bypass' or \
    test[i]=='attachments' or \
    test[i]=='xero' or \
    test[i]=='private' or \
    test[i]=='started' or \
    test[i]=='opening' or \
    test[i]=='scale' or \
    test[i]=='contains' or \
    test[i]=='ways' or \
    test[i]=='trusted' or \
    test[i]=='https' or \
    test[i]=='feature' or \
    test[i]=='clicks' or \
    test[i]=='hosting' or \
    test[i]=='view' or \
    test[i]=='log' or \
    test[i]=='trend' or \
    test[i]=='zix' or \
    test[i]=='trust' or \
    test[i]=='fraudulent' or \
    test[i]=='portal' or \
    test[i]=='types' or \
    test[i]=='impersonating' or \
    test[i]=='containing' or \
    test[i]=='important' or \
    test[i]=='senior' or \
    test[i]=='clicked' or \
    test[i]=='hit' or \
    test[i]=='key' or \
    test[i]=='never' or \
    test[i]=='long' or \
    test[i]=='breach' or \
    test[i]=='especially' or \
    test[i]=='makes' or \
    test[i]=='original' or \
    test[i]=='want' or \
    test[i]=='threats' or \
    test[i]=='released' or \
    test[i]=='go' or \
    test[i]=='php' or \
    test[i]=='she' or \
    test[i]=='controls' or \
    test[i]=='evade' or \
    test[i]=='seems' or \
    test[i]=='products' or \
    test[i]=='saw' or \
    test[i]=='kind' or \
    test[i]=='months' or \
    test[i]=='registered' or \
    test[i]=='statement' or \
    test[i]=='comment' or \
    test[i]=='effort' or \
    test[i]=='off' or \
    test[i]=='too' or \
    test[i]=='nimzaloader' or \
    test[i]=='list' or \
    test[i]=='contacts' or \
    test[i]=='language' or \
    test[i]=='risk' or \
    test[i]=='event' or \
    test[i]=='date' or \
    test[i]=='delivery' or \
    test[i]=='simple' or \
    test[i]=='actual' or \
    test[i]=='month' or \
    test[i]=='rather' or \
    test[i]=='execution' or \
    test[i]=='warning' or \
    test[i]=='sparrow' or \
    test[i]=='attached' or \
    test[i]=='downloads' or \
    test[i]=='state' or \
    test[i]=='interest' or \
    test[i]=='customer' or \
    test[i]=='harvesting' or \
    test[i]=='computer' or \
    test[i]=='among' or \
    test[i]=='test' or \
    test[i]=='phish' or \
    test[i]=='giving' or \
    test[i]=='infected' or \
    test[i]=='command' or \
    test[i]=='human' or \
    test[i]=='says' or \
    test[i]=='numbers' or \
    test[i]=='elizabeth' or \
    test[i]=='united' or \
    test[i]=='made' or \
    test[i]=='sms' or \
    test[i]=='individuals' or \
    test[i]=='silver' or \
    test[i]=='custom' or \
    test[i]=='awareness' or \
    test[i]=='upon' or \
    test[i]=='massive' or \
    test[i]=='wordpress' or \
    test[i]=='spotted' or \
    test[i]=='industries' or \
    test[i]=='leveraged' or \
    test[i]=='place' or \
    test[i]=='again' or \
    test[i]=='great' or \
    test[i]=='methods' or \
    test[i]=='invoice' or \
    test[i]=='aimed' or \
    test[i]=='rat' or \
    test[i]=='current' or \
    test[i]=='critical' or \
    test[i]=='simply' or \
    test[i]=='package' or \
    test[i]=='montalbano' or \
    test[i]=='best' or \
    test[i]=='put' or \
    test[i]=='things' or \
    test[i]=='single' or \
    test[i]=='isn' or \
    test[i]=='others' or \
    test[i]=='small' or \
    test[i]=='provider' or \
    test[i]=='taken' or \
    test[i]=='sharing' or \
    test[i]=='published' or \
    test[i]=='uncovered' or \
    test[i]=='vector' or \
    test[i]=='creating' or \
    test[i]=='dridex' or \
    test[i]=='enough' or \
    test[i]=='non' or \
    test[i]=='stage' or \
    test[i]=='does' or \
    test[i]=='adversary' or \
    test[i]=='director' or \
    test[i]=='phishing':
        del test[i]
        i = i-1
    i = i+1

# %%
test
# Out:
# ['abused',
#  'aggah',
#  'spear',
#  'pakistan',
#  'warzone',
#  'manufacturing',
#  'companies',
#  'taiwan',
#  'south',
#  'korea',
#  'target',
#  'manufacturers',
#  'asia',
#  'spear',
#  'delivers',
#  'warzone',
#  'commodity',
#  'infostealer',
#  'widely',
#  'purchase',
#  'criminal',
#  'forums',
#  'aggah',
#  'believed',
#  'affiliated',
#  'pakistan',
#  'delivering',
#  'spreading',
#  'manufacturing',
#  'companies',
#  'taiwan',
#  'south',
#  'korea',
#  'anomali',
#  'began',
#  'early',
#  'spoofed',
#  'email',
#  'appearing',
#  'originate',
#  'manufacturers',
#  'signaling',
#  'aggah',
#  'infosec',
#  'insiders',
#  'newsletter',
#  'spoofed',
#  'business',
#  'business',
#  'b2b',
#  'email',
#  'targeted',
#  'industry',
#  'consistent',
#  'aggah',
#  'gould',
#  'rory',
#  'gould',
#  'anomali',
#  'palo',
#  'alto',
#  'unit',
#  'aggah',
#  'targeting',
#  'entities',
#  'arab',
#  'emirates',
#  'later',
#  'revengerat',
#  'typically',
#  'aims',
#  'targets',
#  'thought',
#  'gorgon',
#  'pakistani',
#  'targeting',
#  'western',
#  'governments',
#  'association',
#  'proven',
#  'tend',
#  'agree',
#  'urdu',
#  'speaking',
#  'originated',
#  'pakistan',
#  'anomali',
#  'targets',
#  'aggah',
#  'fon',
#  'star',
#  'international',
#  'taiwan',
#  'manufacturing',
#  'company',
#  'fomotech',
#  'taiwanese',
#  'engineering',
#  'company',
#  'hyundai',
#  'electric',
#  'korean',
#  'power',
#  'company',
#  'target',
#  'manufacturers',
#  'suppliers',
#  'target',
#  'infiltrate',
#  'high',
#  'defunct',
#  'revil',
#  'gang',
#  'successfully',
#  'deployed',
#  'quanta',
#  'taiwanese',
#  'supplier',
#  'apple',
#  'ahead',
#  'big',
#  'apple',
#  'product',
#  'revil',
#  'stole',
#  'quanta',
#  'blueprints',
#  'apple',
#  'operators',
#  'threatened',
#  'release',
#  'spill',
#  'beans',
#  'pressure',
#  'company',
#  'pay',
#  'ahead',
#  'apple',
#  'spring',
#  'loaded',
#  'exploiting',
#  'aggah',
#  'spear',
#  'begins',
#  'email',
#  'masquerading',
#  'foodhub',
#  'co',
#  'uk',
#  'online',
#  'food',
#  'kingdom',
#  'email',
#  'body',
#  'shipping',
#  'powerpoint',
#  'named',
#  'purchase',
#  'pdf',
#  'ppam',
#  'obfuscated',
#  'macros',
#  'mshta',
#  'mail',
#  'hoteloscar',
#  'images',
#  'hoteloscar',
#  'hotel',
#  'india',
#  'scripts',
#  'throughout',
#  'scripts',
#  'appeared',
#  'indicating',
#  'exploited',
#  'anti',
#  'debugging',
#  'setinterval',
#  'detect',
#  'debugger',
#  'sends',
#  'setinterval',
#  'infinite',
#  'loop',
#  'debugger',
#  'detected',
#  'debugging',
#  'checks',
#  'returned',
#  'dlsc',
#  'af',
#  'wp',
#  'admin',
#  'buy',
#  'food',
#  'distributor',
#  'afghanistan',
#  'eventually',
#  'powershell',
#  'load',
#  'hex',
#  'encoded',
#  'payloads',
#  'ultimate',
#  'warzone',
#  'purchase',
#  'dark',
#  'warzone',
#  'commodity',
#  'cracked',
#  'versions',
#  'github',
#  'reuses',
#  'ave',
#  'maria',
#  'stealer',
#  'capabilities',
#  'warzone',
#  'privilege',
#  'escalation',
#  'keylogging',
#  'shell',
#  'downloading',
#  'executing',
#  'manager',
#  'persistence',
#  'uac',
#  'defender',
#  'path',
#  'powershell',
#  'exclude',
#  'privilege',
#  'escalation',
#  'warzone',
#  'carried',
#  'sdclt',
#  'backup',
#  'utility',
#  'anomali',
#  'evidence',
#  'aggah',
#  'handiwork',
#  'powerpoint',
#  'macros',
#  'obfuscated',
#  'payloads',
#  'powershell',
#  'typically',
#  'hex',
#  'encoded',
#  'scripts',
#  'embedded',
#  'themes',
#  'aforementioned',
#  'spoofed',
#  'b2b',
#  'email',
#  'target',
#  'industry',
#  'doj',
#  'charges',
#  'rhode',
#  'island',
#  'woman',
#  'scheme',
#  'politicians',
#  'diana',
#  'lebeau',
#  'allegedly',
#  'tried',
#  'candidates',
#  'public',
#  'office',
#  'associates',
#  'microsoft',
#  'department',
#  'justice',
#  'doj',
#  'charged',
#  'woman',
#  'rhode',
#  'island',
#  'candidates',
#  'political',
#  'office',
#  'associates',
#  'impersonated',
#  'workers',
#  'microsoft',
#  'providing',
#  'attorney',
#  'office',
#  'district',
#  'massachusetts',
#  'charged',
#  'diana',
#  'lebeau',
#  'cranston',
#  'attempted',
#  'unauthorized',
#  'protected',
#  'press',
#  'release',
#  'doj',
#  'charge',
#  'relates',
#  'lebeau',
#  'allegedly',
#  'mounted',
#  'beginning',
#  'staffers',
#  'unnamed',
#  'candidate',
#  'political',
#  'office',
#  'political',
#  'candidate',
#  'associates',
#  'doj',
#  'assistant',
#  'attorney',
#  'seth',
#  'kosto',
#  'prosecuting',
#  'came',
#  'phases',
#  'targets',
#  'lebeau',
#  'allegedly',
#  'typical',
#  'identity',
#  'associates',
#  'try',
#  'complying',
#  'messages',
#  'authorities',
#  'impersonated',
#  'candidates',
#  'phase',
#  'phase',
#  'sets',
#  'emails',
#  'claimed',
#  'managers',
#  'co',
#  'chairs',
#  'spreadsheet',
#  'connected',
#  'google',
#  'solicited',
#  'doj',
#  'lebeau',
#  'allegedly',
#  'targeted',
#  'candidate',
#  'spouse',
#  'co',
#  'workers',
#  'messages',
#  'appeared',
#  'microsoft',
#  'employee',
#  'workplace',
#  'desk',
#  'emails',
#  'requested',
#  'computers',
#  'adding',
#  'spreadsheets',
#  'mimicked',
#  'appearance',
#  'employer',
#  'doj',
#  'phase',
#  'came',
#  'later',
#  'lebeau',
#  'allegedly',
#  'emails',
#  'targeting',
#  'candidate',
#  'political',
#  'office',
#  'claimed',
#  'candidate',
#  'cable',
#  'emails',
#  'false',
#  'ostensibly',
#  'purpose',
#  'addressing',
#  'issue',
#  'candidate',
#  'required',
#  'lebeau',
#  'impersonated',
#  'candidate',
#  'online',
#  'chats',
#  'cable',
#  'reset',
#  'obtain',
#  'candidate',
#  'doj',
#  'lenient',
#  'lebeau',
#  'faces',
#  'sentence',
#  'prison',
#  'supervised',
#  'release',
#  'fine',
#  'forfeiture',
#  'charge',
#  'takes',
#  'lebeau',
#  'act',
#  'political',
#  'motive',
#  'benefit',
#  'foreign',
#  'government',
#  'instrumentality',
#  'agent',
#  'doj',
#  'expert',
#  'criticized',
#  'leniency',
#  'charge',
#  'sentence',
#  'suggesting',
#  'seriously',
#  'foreign',
#  'entity',
#  'unexpected',
#  'outcome',
#  'charging',
#  'indicate',
#  'lebeau',
#  'acted',
#  'political',
#  'motives',
#  'foreign',
#  'government',
#  'instrumentality',
#  'agent',
#  'saryu',
#  'nayyar',
#  'ceo',
#  'analytics',
#  'gurucul',
#  'email',
#  'motive',
#  'subjects',
#  'care',
#  'politically',
#  'motivated',
#  'albeit',
#  'domestic',
#  'nayyar',
#  'suggested',
#  'given',
#  'toxicity',
#  'drastic',
#  'polarization',
#  'political',
#  'climate',
#  'states',
#  'extreme',
#  'views',
#  'extreme',
#  'lebeau',
#  'motives',
#  'lightly',
#  'woman',
#  'motive',
#  'inquiring',
#  'minds',
#  'feds',
#  'shut',
#  'covid',
#  'vaccine',
#  'freevaccinecovax',
#  'org',
#  'claimed',
#  'biotech',
#  'company',
#  'info',
#  'visitors',
#  'nefarious',
#  'purposes',
#  'federal',
#  'law',
#  'enforcement',
#  'maryland',
#  'shut',
#  'targeting',
#  'immigrant',
#  'communities',
#  'claimed',
#  'company',
#  'developing',
#  'covid',
#  'vaccine',
#  'purpose',
#  'future',
#  'cybercriminal',
#  'attorney',
#  'office',
#  'district',
#  'maryland',
#  'homeland',
#  'investigations',
#  'hsi',
#  'baltimore',
#  'seized',
#  'freevaccinecovax',
#  'org',
#  'purported',
#  'biotechnology',
#  'company',
#  'developing',
#  'vaccine',
#  'covid',
#  'virus',
#  'release',
#  'office',
#  'posted',
#  'collecting',
#  'visited',
#  'nefarious',
#  'purposes',
#  'deployment',
#  'trademarked',
#  'logos',
#  'pfizer',
#  'organization',
#  'nations',
#  'high',
#  'commissioner',
#  'refugees',
#  'unhcr',
#  'home',
#  'dupe',
#  'visitors',
#  'thinking',
#  'release',
#  'collected',
#  'visitor',
#  'drop',
#  'menu',
#  'select',
#  'city',
#  'apply',
#  'downloading',
#  'pdf',
#  'computers',
#  'pdf',
#  'offered',
#  'written',
#  'cyrillic',
#  'suggesting',
#  'fraudsters',
#  'targeting',
#  'immigrant',
#  'communities',
#  'former',
#  'soviet',
#  'countries',
#  'belarus',
#  'khazakstan',
#  'russia',
#  'turkmenistan',
#  'ukraine',
#  'cyrillic',
#  'native',
#  'languages',
#  'analysis',
#  'conducted',
#  'hsi',
#  'indicated',
#  'located',
#  'strasbourg',
#  'france',
#  'registrant',
#  'country',
#  'listed',
#  'russia',
#  'scary',
#  'thought',
#  'hsi',
#  'wants',
#  'public',
#  'understand',
#  'guy',
#  'needs',
#  'defraud',
#  'americans',
#  'search',
#  'covd',
#  'ability',
#  'combined',
#  'intent',
#  'james',
#  'mancuso',
#  'special',
#  'agent',
#  'charge',
#  'hsi',
#  'baltimore',
#  'field',
#  'office',
#  'must',
#  'perpetrators',
#  'deter',
#  'committing',
#  'crimes',
#  'unsuspecting',
#  'vulnerable',
#  'greets',
#  'message',
#  'seized',
#  'federal',
#  'government',
#  'redirects',
#  'seizing',
#  'parties',
#  'commit',
#  'crimes',
#  'feds',
#  'itself',
#  'illustrate',
#  'useful',
#  'covid',
#  'pandemic',
#  'cash',
#  'misery',
#  'eric',
#  'howes',
#  'principal',
#  'lab',
#  'knowbe4',
#  'email',
#  'bogus',
#  'vaccine',
#  'offers',
#  'wide',
#  'range',
#  'social',
#  'engineering',
#  'schemes',
#  'offers',
#  'vaccine',
#  'supplies',
#  'bogus',
#  'investment',
#  'schemes',
#  'covid',
#  'gift',
#  'keeps',
#  'artists',
#  'covid',
#  'vax',
#  'attracts',
#  'crooks',
#  'indeed',
#  'news',
#  'vaccines',
#  'covid',
#  'extensively',
#  'focused',
#  'plans',
#  'vaccines',
#  'espionage',
#  'aiming',
#  'benefit',
#  'financially',
#  'vaccine',
#  'acknowledged',
#  'acting',
#  'attorney',
#  'jonathan',
#  'lenzner',
#  'seizure',
#  'ninth',
#  'shut',
#  'seeking',
#  'illegally',
#  'profit',
#  'covid',
#  'pandemic',
#  'indeed',
#  'vaccine',
#  'rollout',
#  'scams',
#  'sophisticated',
#  'zebrocy',
#  'widespread',
#  'attention',
#  'distribution',
#  'vaccines',
#  'seizure',
#  'drop',
#  'bucket',
#  'howes',
#  'authorities',
#  'lauded',
#  'shutting',
#  'wonders',
#  'pushing',
#  'schemes',
#  'dozens',
#  'moreover',
#  'parties',
#  'lenzner',
#  'federal',
#  'government',
#  'aggressively',
#  'prosecute',
#  'fraudsters',
#  'aim',
#  'prey',
#  'misunderstanding',
#  'vaccine',
#  'distributed',
#  'misconceptions',
#  'present',
#  'immigrant',
#  'communities',
#  'inherent',
#  'understanding',
#  'medical',
#  'rollout',
#  'vaccine',
#  'members',
#  'public',
#  'unsolicited',
#  'emails',
#  'remember',
#  'covid',
#  'vaccine',
#  'sale',
#  'press',
#  'spawn',
#  'strains',
#  'lisa',
#  'vaas',
#  'strains',
#  'professionally',
#  'coded',
#  'sophistication',
#  'launched',
#  'resourced',
#  'nearly',
#  'hijacked',
#  'waves',
#  'swamped',
#  'organizations',
#  'delivered',
#  'families',
#  'fireeye',
#  'mandiant',
#  'dubbed',
#  'hitherto',
#  'unseen',
#  'strains',
#  'doubledrag',
#  'doubledrop',
#  'doubleback',
#  'mandiant',
#  'trifecta',
#  'spear',
#  'twice',
#  'wide',
#  'swath',
#  'worldwide',
#  'dec',
#  'wave',
#  'launched',
#  'dec',
#  'dec',
#  'primary',
#  'target',
#  'waves',
#  'emea',
#  'asia',
#  'australia',
#  'shared',
#  'equal',
#  'suffering',
#  'wave',
#  'schlubs',
#  'mandiant',
#  'tracks',
#  'unc2529',
#  'guys',
#  'pros',
#  'given',
#  'considerable',
#  'infrastructure',
#  'disposal',
#  'carefully',
#  'crafted',
#  'professionally',
#  'coded',
#  'sophistication',
#  'unc2529',
#  'seem',
#  'experienced',
#  'resourced',
#  'unc2529',
#  'gang',
#  'researched',
#  'targets',
#  'tailoring',
#  'email',
#  'lines',
#  'intended',
#  'masqueraded',
#  'executive',
#  'california',
#  'electronics',
#  'manufacturer',
#  'emails',
#  'targeted',
#  'slew',
#  'medical',
#  'defense',
#  'emails',
#  'lines',
#  'company',
#  'pretending',
#  'zoho',
#  'webinar',
#  'promo',
#  'join',
#  'fortifying',
#  'business',
#  'ddos',
#  'cryptojacking',
#  'live',
#  'roundtable',
#  'edt',
#  'webinar',
#  'sponsored',
#  'zoho',
#  'manageengine',
#  'ecosystem',
#  'unc2529',
#  'consists',
#  'downloader',
#  'doubledrag',
#  'excel',
#  'embedded',
#  'macro',
#  'dropper',
#  'doubledrop',
#  'backdoor',
#  'doubleback',
#  'infection',
#  'starts',
#  'emails',
#  'rigged',
#  'downloader',
#  'heavily',
#  'obfuscated',
#  'analysis',
#  'executed',
#  'doubledrag',
#  'tries',
#  'dropper',
#  'doubledrop',
#  'doubledrop',
#  'obfuscated',
#  'powershell',
#  'plant',
#  'backdoor',
#  'memory',
#  'flavors',
#  'bit',
#  'bit',
#  'doubleback',
#  'backdoor',
#  'backdoor',
#  'gets',
#  'inserting',
#  'plugins',
#  'reporting',
#  'controllers',
#  'backdoor',
#  'loads',
#  'plugins',
#  'enters',
#  'communication',
#  'loop',
#  'fetching',
#  'commands',
#  'dispatching',
#  'mandiant',
#  'describes',
#  'interesting',
#  'whole',
#  'ecosystem',
#  'downloader',
#  'exists',
#  'rest',
#  'components',
#  'serialized',
#  'registry',
#  'database',
#  'somewhat',
#  'harder',
#  'antivirus',
#  'engines',
#  'chugging',
#  'away',
#  'unc2529',
#  'firepower',
#  'run',
#  'mandiant',
#  'nearly',
#  'supported',
#  'phases',
#  'meanwhile',
#  'diligence',
#  'researching',
#  'targets',
#  'concoct',
#  'entice',
#  'worked',
#  'hard',
#  'obfuscate',
#  'components',
#  'fileless',
#  'runs',
#  'memory',
#  'infection',
#  'storing',
#  'hard',
#  'analysis',
#  'telemetry',
#  'cisco',
#  'fileless',
#  'severity',
#  'endpoints',
#  'fileless',
#  'helped',
#  'flummox',
#  'mandiant',
#  'coded',
#  'extensible',
#  'backdoor',
#  'dimiter',
#  'andonov',
#  'principal',
#  'reverse',
#  'engineer',
#  'mandiant',
#  'email',
#  'afternoon',
#  'employed',
#  'ecosystem',
#  'specifically',
#  'less',
#  'serialization',
#  'novel',
#  'per',
#  'se',
#  'result',
#  'components',
#  'harder',
#  'detected',
#  'andonov',
#  'mandiant',
#  'assumes',
#  'profit',
#  'wide',
#  'ranging',
#  'targets',
#  'geography',
#  'industry',
#  'suggests',
#  'crime',
#  'motive',
#  'doubleback',
#  'progress',
#  'expects',
#  'unc2529',
#  'keep',
#  'pulled',
#  'mandiant',
#  'calls',
#  'double',
#  'trifecta',
#  'standard',
#  'issue',
#  'advice',
#  'applies',
#  'andonov',
#  'vectors',
#  ...]

# %%
result_list = pd.Series(test).value_counts().head(20)
result_list
# Out:
# emails        42
# email         41
# targeting     26
# targeted      26
# spear         24
# paypal        22
# company       19
# government    17
# scam          14
# target        13
# librarian     13
# analysis      13
# silent        13
# cobalt        12
# school        12
# skimming      12
# lebeau        11
# spoofed       11
# ta800         11
# iran          11
# dtype: int64

# %%
# 결과를 csv 파일로 저장
df = pd.DataFrame.from_dict(test)
df.to_csv('피싱 유형별 단어 빈도 분석_Spear Phishing.csv')
